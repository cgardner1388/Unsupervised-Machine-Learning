# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
### Data Preparation

# %%
file_path = Path("crypto_data.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
df.dtypes
# Out:
# Unnamed: 0          object
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
#Filter the data to only true values
trading_df = df.loc[df['IsTrading'] == True]
trading_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
#Show that only true values are in the table
trading_df['IsTrading'].value_counts()
# Out:
# True    1144
# Name: IsTrading, dtype: int64

# %%
#Drop the IsTrading column
crypto_trading_df = trading_df.drop(columns=['IsTrading'])
crypto_trading_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 1        365    365Coin       X11   PoW/PoS              NaN      2300000000
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 3        611  SixEleven   SHA-256       PoW              NaN          611000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
#Remove the null values from the dataframe
crypto_trading_dropna_df = crypto_trading_df.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)
crypto_trading_dropna_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %%
#48 Rows with zero
crypto_trading_dropna_df['TotalCoinsMined'].value_counts()
# Out:
# 0.000000e+00    152
# 1.000000e+09      7
# 1.000000e+08      7
# 2.500000e+07      2
# 2.000000e+07      2
#                ...
# 2.951355e+08      1
# 3.082571e+10      1
# 2.108935e+07      1
# 1.207310e+06      1
# 7.847417e+06      1
# Name: TotalCoinsMined, Length: 520, dtype: int64

# %%
#Remove anything with a zero in the Total Coins Mined column
cleaned_crypto_df = crypto_trading_dropna_df.loc[crypto_trading_dropna_df['TotalCoinsMined'] > 0]
cleaned_crypto_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...

# %%
#Remove the column CoinName
final_cleaned_crypto_df= cleaned_crypto_df.drop(columns=['CoinName'])
final_cleaned_crypto_df
# Out:
#      Unnamed: 0    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0            42       Scrypt   PoW/PoS     4.199995e+01              42
# 2           404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5          1337          X13   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      SHA-256       PoW     1.792718e+07        21000000
# 8           ETH       Ethash       PoW     1.076842e+08               0
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# 1242        GAP       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245        BDX  CryptoNight       PoW     9.802226e+08      1400222610
# 1246        ZEN     Equihash       PoW     7.296538e+06        21000000
# 1247        XBC       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
###convert the remaining features with text values, `Algorithm` and `ProofType`, into numerical data. To accomplish this task, use Pandas to create dummy variables. Examine the number of rows and columns of your dataset now. How did they change?
###Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.
cleaned_crypto_ml_df = pd.get_dummies(data=final_cleaned_crypto_df, columns=['Algorithm', 'ProofType'])
cleaned_crypto_ml_df.head()
# Out:
#   Unnamed: 0  TotalCoinsMined TotalCoinSupply  \
# 0         42     4.199995e+01              42
# 2        404     1.055185e+09       532000000
# 5       1337     2.927942e+10    314159265359
# 7        BTC     1.792718e+07        21000000
# 8        ETH     1.076842e+08               0
#
#    Algorithm_1GB AES Pattern Search  Algorithm_536  Algorithm_Argon2d  \
# 0                                 0              0                  0
# 2                                 0              0                  0
# 5                                 0              0                  0
# 7                                 0              0                  0
# 8                                 0              0                  0
#
#    Algorithm_BLAKE256  Algorithm_Blake  Algorithm_Blake2S  Algorithm_Blake2b  \
# 0                   0                0                  0                  0
# 2                   0                0                  0                  0
# ...

# %%
final_cleaned_crypto_ml_df = cleaned_crypto_ml_df.set_index('Unnamed: 0')
final_cleaned_crypto_ml_df
# Out:
#             TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Unnamed: 0
# 42             4.199995e+01              42                                 0
# 404            1.055185e+09       532000000                                 0
# 1337           2.927942e+10    314159265359                                 0
# BTC            1.792718e+07        21000000                                 0
# ETH            1.076842e+08               0                                 0
# ...                     ...             ...                               ...
# ZEPH           2.000000e+09      2000000000                                 0
# GAP            1.493105e+07       250000000                                 0
# BDX            9.802226e+08      1400222610                                 0
# ZEN            7.296538e+06        21000000                                 0
# XBC            1.283270e+05         1000000                                 0
#
# ...

# %%
###Get dummies, scale, PCA, PCA needs to be on the scale data

# %%
crypto_scaled_df = StandardScaler().fit_transform(final_cleaned_crypto_ml_df)

# %%
### Dimensionality Reduction
### Use PCA

# %%
crypto_scaled_df.shape
# Out:
# (532, 98)

# %%
# Initialize PCA model
pca = PCA(n_components=.90)

# %%
# Get two principal components for the data.
crypto_pca = pca.fit_transform(crypto_scaled_df)
crypto_pca.shape
# Out:
# (532, 74)

# %%
# Transform PCA data to a DataFrame
crypto_pca_df = pd.DataFrame(crypto_pca)
crypto_pca_df.head()
# Out:
#          0         1         2         3             4             5   \
# 0 -0.335099  1.032189 -0.590713  0.001397  8.903525e-15  3.715567e-12
# 1 -0.318434  1.032331 -0.591126  0.001386  8.797456e-15  3.685202e-12
# 2  2.305468  1.656383 -0.683617  0.004731  1.292867e-14  1.259214e-11
# 3 -0.145184 -1.320593  0.192813 -0.001229 -2.452485e-15 -3.268574e-12
# 4 -0.151768 -2.036192  0.396182 -0.001705 -1.119309e-14 -4.534708e-12
#
#              6         7         8         9   ...            64  \
# 0 -1.716189e-14 -0.007129 -1.319756 -0.051813  ... -2.210782e-16
# 1 -1.704862e-14 -0.007739 -1.322514 -0.056674  ...  7.921450e-17
# 2 -2.400344e-14 -0.054781 -1.542879 -0.943951  ...  8.752073e-15
# 3  4.249357e-15 -0.002071  0.281463  0.251862  ... -2.655003e-15
# 4  1.170787e-14  0.027735  0.519099  0.188820  ... -6.843734e-14
#
#              65            66            67            68            69  \
# 0 -6.883168e-16  2.282140e-15 -3.661557e-15  1.430694e-15  5.554638e-16
# ...

# %%
final_crypto_pca_df = crypto_pca_df[[1,2,3]]
final_crypto_pca_df
# Out:
#             1         2         3
# 0    1.032189 -0.590713  0.001397
# 1    1.032331 -0.591126  0.001386
# 2    1.656383 -0.683617  0.004731
# 3   -1.320593  0.192813 -0.001229
# 4   -2.036192  0.396182 -0.001705
# ..        ...       ...       ...
# 527  0.822241 -0.071160 -0.008206
# 528  1.032071 -0.590740  0.001399
# 529 -2.312308  0.421515 -0.001319
# 530 -2.049336  0.412968 -0.001745
# 531  0.821195 -0.276327  0.000555
#
# [532 rows x 3 columns]

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
# Initialize t-SNE model
tsne = TSNE(learning_rate=35)

# %%
# Reduce dimensions
tsne_features = tsne.fit_transform(final_crypto_pca_df)

# %%
# Prepare to plot the dataset

# The first column of transformed features
final_crypto_pca_df['x'] = tsne_features[:,0]

# The second column of transformed features
final_crypto_pca_df['y'] = tsne_features[:,1]
# Out:
# <ipython-input-26-9e1d10f8472c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_crypto_pca_df['x'] = tsne_features[:,0]
# <ipython-input-26-9e1d10f8472c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_crypto_pca_df['y'] = tsne_features[:,1]

# %%
plt.scatter(final_crypto_pca_df['x'], final_crypto_pca_df['y'])
plt.show()

# %%
###Create an elbow plot to identify the best number of clusters. 
###Use a for-loop to determine the inertia for each `k` between 1 through 10. 
###Determine, if possible, where the elbow of the plot is, and at which value of `k` it appears.

# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Finding the best value for k
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(final_crypto_pca_df)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
### Recommendation

###Based on your findings, make a brief (1-2 sentences) recommendation to your clients. 
###Can the cryptocurrencies be clustered together? If so, into how many clusters?

# %%
### Yes, the cryptocurrencies can be clustered together based on the above graph. 
### The elbow indicates that the optimal number of clusters is going to be 4.
